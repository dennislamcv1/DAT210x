# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module4- Lab3

# %% [markdown]
# This code is intentionally missing! Read the directions on the course lab page!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
#import assignment2_helper as helper

# %%
# Look pretty...
matplotlib.style.use('ggplot')


# Do * NOT * alter this line, until instructed!
scaleFeatures = False

# %%
df = pd.read_csv('Datasets/kidney_disease.csv')

# %%
labels = ['red' if i=='ckd' else 'green' for i in df.classification]

# %%
df.drop(labels = ['id', 'classification', 'rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane'], axis = 1, inplace = True)

# %%
df.pcv = pd.to_numeric(df.pcv, errors = 'coerce')
df.wc = pd.to_numeric(df.wc, errors = 'coerce')
df.rc = pd.to_numeric(df.rc, errors = 'coerce')

# %%
df.dropna(axis = 0, how = 'any', inplace = True)
df
# Out:
#       age    bp     sg   al   su    bgr     bu   sc    sod  pot  hemo   pcv  \
# 3    48.0  70.0  1.005  4.0  0.0  117.0   56.0  3.8  111.0  2.5  11.2  32.0
# 5    60.0  90.0  1.015  3.0  0.0   74.0   25.0  1.1  142.0  3.2  12.2  39.0
# 9    53.0  90.0  1.020  2.0  0.0   70.0  107.0  7.2  114.0  3.7   9.5  29.0
# 11   63.0  70.0  1.010  3.0  0.0  380.0   60.0  2.7  131.0  4.2  10.8  32.0
# 12   68.0  70.0  1.015  3.0  1.0  208.0   72.0  2.1  138.0  5.8   9.7  28.0
# ..    ...   ...    ...  ...  ...    ...    ...  ...    ...  ...   ...   ...
# 395  55.0  80.0  1.020  0.0  0.0  140.0   49.0  0.5  150.0  4.9  15.7  47.0
# 396  42.0  70.0  1.025  0.0  0.0   75.0   31.0  1.2  141.0  3.5  16.5  54.0
# 397  12.0  80.0  1.020  0.0  0.0  100.0   26.0  0.6  137.0  4.4  15.8  49.0
# 398  17.0  60.0  1.025  0.0  0.0  114.0   50.0  1.0  135.0  4.9  14.2  51.0
# 399  58.0  80.0  1.025  0.0  0.0  131.0   18.0  1.1  141.0  3.5  15.8  53.0
#
#           wc   rc
# 3     6700.0  3.9
# 5     7800.0  4.4
# 9    12100.0  3.7
# 11    4500.0  3.8
# 12   12200.0  3.4
# ..       ...  ...
# 395   6700.0  4.9
# 396   7800.0  6.2
# 397   6600.0  5.4
# 398   7200.0  5.9
# 399   6800.0  6.1
#
# [203 rows x 14 columns]

# %%
if scaleFeatures: df = helper.scaleFeatures(df)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
pca.fit(df)
T = pca.transform(df)

# %%
ax = helper.drawVectors(T, pca.components_, df.columns.values, plt, scaleFeatures)
T = pd.DataFrame(T)
T.columns = ['component1', 'component2']
T.plot.scatter(x='component1', y='component2', marker='o', c = labels, alpha=0.75, ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8042e44df271> in <module>
# ----> 1 ax = helper.drawVectors(T, pca.components_, df.columns.values, plt, scaleFeatures)
#       2 T = pd.DataFrame(T)
#       3 T.columns = ['component1', 'component2']
#       4 T.plot.scatter(x='component1', y='component2', marker='o', c = labels, alpha=0.75, ax=ax)
#       5 plt.show()
#
# NameError: name 'helper' is not defined
